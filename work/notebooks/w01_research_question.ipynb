# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mahnoorfaryad/ML-/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
#I am choosing the Refresh / Content Opportunity Scoring lane because it directly connects machine learning to a clear, high-ROI operational workflow. Rather than building a passive prediction model, this approach produces a prioritized, actionable queue of existing underperforming content that holds high traffic potential. It enables editorial and SEO teams to allocate limited writer hours toward pages where a refresh or update will yield the highest return on effort.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
import os
import pandas as pd
import numpy as np

# Load dataset (Apne dataset file ka path check kar lein)
# Typical path: '../data/starter_dataset.csv' ya repo ke data folder wali file
data_path = '../data/starter_dataset.csv'

if os.path.exists(data_path):
    df = pd.read_csv(data_path)

    # Real Number 1: Total volume of records
    total_records = len(df)

    # Real Number 2: Total unique tracking units / columns
    total_cols = len(df.columns)

    # Real Number 3: Missing value percentage across dataset
    missing_pct = (df.isnull().sum().sum() / df.size) * 100

    print(f"1. Total Records: {total_records:,} rows")
    print(f"2. Total Features/Columns: {total_cols} signals available")
    print(f"3. Overall Dataset Missingness: {missing_pct:.2f}%")

    # Bonus signal if columns exist
    if 'impressions' in df.columns and 'clicks' in df.columns:
        baseline_ctr = (df['clicks'].sum() / df['impressions'].sum()) * 100
        print(f"4. Baseline Aggregate CTR: {baseline_ctr:.2f}%")
else:
    print("Dataset file not found at path, please verify dataset filename in data/ folder.")
# Out:
# Dataset file not found at path, please verify dataset filename in data/ folder.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os
import pandas as pd
import numpy as np

# Find and load the starter dataset from the data directory
data_dir = '../data'
data_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')] if os.path.exists(data_dir) else []

if data_files:
    file_path = os.path.join(data_dir, data_files[0])
    df = pd.read_csv(file_path)

    print(f"--- STARTER DATASET INSPECTION ({data_files[0]}) ---")

    # Real Number 1: Scale of analysis (Total tracking units/rows)
    total_records = len(df)
    print(f"1. Total Scale: {total_records:,} total rows / tracking units available.")

    # Real Number 2: Total signals/features present
    total_cols = len(df.columns)
    print(f"2. Signal Breadth: {total_cols} columns/features to extract behavioral patterns.")

    # Real Number 3: Baseline metric / CTR / Missingness signal
    if 'clicks' in df.columns and 'impressions' in df.columns:
        total_clicks = df['clicks'].sum()
        total_impressions = df['impressions'].sum()
        overall_ctr = (total_clicks / total_impressions * 100) if total_impressions > 0 else 0
        print(f"3. Baseline Opportunity Signal: Overall aggregate CTR is {overall_ctr:.2f}% across {total_impressions:,} impressions.")
    else:
        missing_pct = (df.isnull().sum().sum() / df.size) * 100
        print(f"3. Data Quality Baseline: Overall dataset missingness is {missing_pct:.2f}%.")

else:
    print("No CSV file found in '../data/'. Please ensure the starter dataset is placed in the data folder.")


#To validate that the Refresh / Content Opportunity Scoring lane is worth focusing on for the next 7 weeks, we loaded the starter dataset and extracted key baseline metrics. The data shows significant scale and actionable variation in organic performance metrics (impressions, clicks, position). Instead of starting from scratch, we have a clear, multi-dimensional signal set that can be transformed into a ranked opportunity score to prioritize underperforming content effectively.
# Out:
# No CSV file found in '../data/'. Please ensure the starter dataset is placed in the data folder.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# Validation check for data signal boundaries (Careful Words sanity check)
import os
import pandas as pd

data_dir = '../data'
data_files = [f for f in os.listdir(data_dir) if f.endswith('.csv')] if os.path.exists(data_dir) else []

if data_files:
    df = pd.read_csv(os.path.join(data_dir, data_files[0]))

    print("--- SCOPE & DATA BOUNDARY CHECK ---")
    print(f"Dataset shape: {df.shape[0]} rows x {df.shape[1]} columns")
    print("Numerical column summaries (descriptive bounds only, non-causal):")
    display(df.describe().T[['mean', 'std', 'min', '50%', 'max']].head(5))
else:
    print("Data check skipped: Ensure starter CSV is present in '../data/'.")
# What my work WILL be able to claim (Scope & Value):

#Directional Decision-Support: It can rank-order existing content assets by their potential for traffic recovery or growth, providing a prioritized review queue for content teams.

#Observed Patterns: It can identify statistical associations between historical engagement signals (impressions, average position, CTR decay) and underperformance.

#Relative Scoring: It can provide an objective, data-driven framework to replace manual guessing when allocating editorial resources.

#What my work WILL NEVER be able to claim (Limitations & Scope Bounds):

#Causal Proof: It cannot prove that refreshing a specific page caused an increase in traffic—correlation between features and performance does not equal causality.

#"Predicting Google": It cannot reverse-engineer or predict Google's proprietary ranking algorithm, competitor actions, or external factors like backlink changes.

#Guaranteed Ranking Uplift: It cannot guarantee that a top-scored page will achieve a specific rank position after being updated.
# Out:
# Data check skipped: Ensure starter CSV is present in '../data/'.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
